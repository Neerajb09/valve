# %%
from ultralytics import YOLO
import cv2
import os

# Load YOLO model for Ascending Aorta detection
aorta_model_path = "/mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Models/yolo_training_ASC1/yolov8_sov_ASC1/weights/best.pt"
aorta_model = YOLO(aorta_model_path).to(device="cuda:6")

# Paths
input_folder = "/mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/Original Data/images/train_augmented"  # Original images
cropped_folder = "/mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train"  # Cropped images
output_folder = "/mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/mapped_predictions"  # Final images with mapped detections

# Create output directory
os.makedirs(output_folder, exist_ok=True)

# Process each cropped image
for frame_file in sorted(os.listdir(cropped_folder)):
    if frame_file.lower().endswith(('.jpg', '.png', '.jpeg')):
        original_path = os.path.join(input_folder, frame_file)  # Corresponding original image
        cropped_path = os.path.join(cropped_folder, frame_file)  # Cropped image
        output_path = os.path.join(output_folder, frame_file)  # Save final output

        # Run YOLO inference for Ascending Aorta detection on cropped image
        results = aorta_model(cropped_path)

        # Load original and cropped images
        original_img = cv2.imread(original_path)
        cropped_img = cv2.imread(cropped_path)
        
        h_original, w_original, _ = original_img.shape  # Original image size
        h_cropped, w_cropped, _ = cropped_img.shape  # Cropped image size

        # Get the crop offset: SOV was detected at y_crop in original image
        y_crop = h_original - h_cropped  # The cropped region starts from y_crop in the original image

        # Get detected objects
        boxes = results[0].boxes  # Bounding boxes
        confs = boxes.conf if boxes is not None else []  # Confidence scores

        # Draw mapped bounding boxes on the original image
        for i in range(len(confs)):
            x1, y1, x2, y2 = map(int, boxes[i].xyxy[0])  # Get box coordinates



            # Draw bounding box on the original image
            cv2.rectangle(original_img, (x1, y1), (x2, y2), (0, 255, 0), 2)
            cv2.putText(original_img, f"Aorta {confs[i]:.2f}", (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        # Save the final image with mapped detections
        cv2.imwrite(output_path, original_img)

print(f"✅ Mapping complete! Final images saved in {output_folder}")
# Out:
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_471.png: 320x640 1 Asc Aorta, 14.8ms
# Speed: 3.1ms preprocess, 14.8ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_471_blur.jpg: 320x640 1 Asc Aorta, 7.5ms
# Speed: 4.6ms preprocess, 7.5ms inference, 1.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_471_brightness_contrast.jpg: 320x640 1 Asc Aorta, 8.7ms
# Speed: 3.2ms preprocess, 8.7ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_471_clahe.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_471_scaling.jpg: 320x640 1 Asc Aorta, 6.6ms
# Speed: 1.5ms preprocess, 6.6ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_474.png: 320x640 1 Asc Aorta, 5.5ms
# Speed: 3.3ms preprocess, 5.5ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_474_blur.jpg: 320x640 1 Asc Aorta, 5.4ms
# Speed: 3.5ms preprocess, 5.4ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_474_brightness_contrast.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_474_clahe.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 3.2ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_474_scaling.jpg: 320x640 1 Asc Aorta, 5.0ms
# Speed: 3.2ms preprocess, 5.0ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_480.png: 320x640 1 Asc Aorta, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_480_blur.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 2.6ms preprocess, 6.2ms inference, 7.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_480_brightness_contrast.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 3.3ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_480_clahe.jpg: 320x640 1 Asc Aorta, 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 12.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A - 3mensio Screen Recording_longitudinal_view_480_scaling.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 6.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_361.png: 256x640 1 Asc Aorta, 3.8ms
# Speed: 0.9ms preprocess, 3.8ms inference, 0.8ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_361_blur.jpg: 256x640 1 Asc Aorta, 6.2ms
# Speed: 1.1ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_361_brightness_contrast.jpg: 256x640 1 Asc Aorta, 6.0ms
# Speed: 1.1ms preprocess, 6.0ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_361_clahe.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 2.1ms preprocess, 3.7ms inference, 8.7ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_361_scaling.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 12.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_423.png: 256x640 1 Asc Aorta, 3.7ms
# Speed: 2.1ms preprocess, 3.7ms inference, 1.5ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_423_blur.jpg: 256x640 1 Asc Aorta, 6.1ms
# Speed: 2.2ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_423_brightness_contrast.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 2.9ms preprocess, 3.7ms inference, 12.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_423_clahe.jpg: 256x640 1 Asc Aorta, 4.4ms
# Speed: 2.9ms preprocess, 4.4ms inference, 0.9ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_423_scaling.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 1.3ms preprocess, 3.7ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_432.png: 256x640 1 Asc Aorta, 3.7ms
# Speed: 1.9ms preprocess, 3.7ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_432_blur.jpg: 256x640 1 Asc Aorta, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 12.1ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_432_brightness_contrast.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 1.7ms preprocess, 3.7ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_432_clahe.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 3.1ms preprocess, 3.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 2 - 3mensio Screen Recording_longitudinal_view_432_scaling.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 1.9ms preprocess, 3.7ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_341.png: 256x640 1 Asc Aorta, 3.6ms
# Speed: 1.4ms preprocess, 3.6ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_341_blur.jpg: 256x640 1 Asc Aorta, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 5.2ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_341_brightness_contrast.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 12.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_341_clahe.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 1.2ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_341_scaling.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 2.5ms preprocess, 3.7ms inference, 12.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_359.png: 256x640 1 Asc Aorta, 3.5ms
# Speed: 1.0ms preprocess, 3.5ms inference, 12.5ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_359_blur.jpg: 256x640 1 Asc Aorta, 8.6ms
# Speed: 3.2ms preprocess, 8.6ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_359_brightness_contrast.jpg: 256x640 1 Asc Aorta, 5.5ms
# Speed: 1.0ms preprocess, 5.5ms inference, 12.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_359_clahe.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 1.3ms preprocess, 3.7ms inference, 8.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_359_scaling.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 1.2ms preprocess, 3.7ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_584.png: 256x640 1 Asc Aorta, 4.1ms
# Speed: 1.5ms preprocess, 4.1ms inference, 1.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_584_blur.jpg: 256x640 1 Asc Aorta, 6.5ms
# Speed: 2.8ms preprocess, 6.5ms inference, 10.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_584_brightness_contrast.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 1.1ms preprocess, 3.7ms inference, 12.3ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_584_clahe.jpg: 256x640 1 Asc Aorta, 3.7ms
# Speed: 2.0ms preprocess, 3.7ms inference, 12.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A A 3 - 3mensio Screen Recording_longitudinal_view_584_scaling.jpg: 256x640 1 Asc Aorta, 6.1ms
# Speed: 1.2ms preprocess, 6.1ms inference, 1.4ms postprocess per image at shape (1, 3, 256, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_184.png: 448x640 1 Asc Aorta, 11.1ms
# Speed: 2.0ms preprocess, 11.1ms inference, 12.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_184_blur.jpg: 448x640 1 Asc Aorta, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_184_brightness_contrast.jpg: 448x640 1 Asc Aorta, 6.2ms
# Speed: 3.1ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_184_clahe.jpg: 448x640 2 Asc Aortas, 3.7ms
# Speed: 2.4ms preprocess, 3.7ms inference, 3.7ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_184_scaling.jpg: 448x640 1 Asc Aorta, 3.8ms
# Speed: 2.6ms preprocess, 3.8ms inference, 12.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_188.png: 448x640 1 Asc Aorta, 4.5ms
# Speed: 2.4ms preprocess, 4.5ms inference, 1.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_188_blur.jpg: 448x640 1 Asc Aorta, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 10.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_188_brightness_contrast.jpg: 448x640 1 Asc Aorta, 6.2ms
# Speed: 3.3ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_188_clahe.jpg: 448x640 1 Asc Aorta, 4.6ms
# Speed: 2.8ms preprocess, 4.6ms inference, 1.2ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_188_scaling.jpg: 448x640 1 Asc Aorta, 6.2ms
# Speed: 2.5ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_75.png: 448x640 1 Asc Aorta, 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 12.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_75_blur.jpg: 448x640 1 Asc Aorta, 3.8ms
# Speed: 1.4ms preprocess, 3.8ms inference, 12.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_75_brightness_contrast.jpg: 448x640 1 Asc Aorta, 3.8ms
# Speed: 4.0ms preprocess, 3.8ms inference, 6.1ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_75_clahe.jpg: 448x640 1 Asc Aorta, 3.8ms
# Speed: 3.0ms preprocess, 3.8ms inference, 12.4ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A H - 3mensio Screen Recording_longitudinal_view_75_scaling.jpg: 448x640 1 Asc Aorta, 3.8ms
# Speed: 2.9ms preprocess, 3.8ms inference, 1.3ms postprocess per image at shape (1, 3, 448, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_189.png: 288x640 1 Asc Aorta, 13.5ms
# Speed: 2.4ms preprocess, 13.5ms inference, 12.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_189_blur.jpg: 288x640 1 Asc Aorta, 19.2ms
# Speed: 3.3ms preprocess, 19.2ms inference, 2.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_189_brightness_contrast.jpg: 288x640 1 Asc Aorta, 3.7ms
# Speed: 2.6ms preprocess, 3.7ms inference, 12.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_189_clahe.jpg: 288x640 1 Asc Aorta, 3.7ms
# Speed: 1.6ms preprocess, 3.7ms inference, 3.5ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_189_scaling.jpg: 288x640 1 Asc Aorta, 3.3ms
# Speed: 0.9ms preprocess, 3.3ms inference, 0.8ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_231.png: 288x640 1 Asc Aorta, 3.5ms
# Speed: 0.8ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_231_blur.jpg: 288x640 1 Asc Aorta, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 12.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_231_brightness_contrast.jpg: 288x640 1 Asc Aorta, 6.2ms
# Speed: 2.5ms preprocess, 6.2ms inference, 3.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_231_clahe.jpg: 288x640 1 Asc Aorta, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_231_scaling.jpg: 288x640 1 Asc Aorta, 4.9ms
# Speed: 1.3ms preprocess, 4.9ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_300.png: 288x640 1 Asc Aorta, 6.2ms
# Speed: 1.3ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_300_blur.jpg: 288x640 1 Asc Aorta, 6.2ms
# Speed: 2.5ms preprocess, 6.2ms inference, 7.1ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_300_brightness_contrast.jpg: 288x640 1 Asc Aorta, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_300_clahe.jpg: 288x640 1 Asc Aorta, 4.8ms
# Speed: 1.3ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A J - 3mensio Screen Recording_longitudinal_view_300_scaling.jpg: 288x640 1 Asc Aorta, 6.2ms
# Speed: 1.8ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 288, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_249.png: 384x640 1 Asc Aorta, 13.5ms
# Speed: 2.9ms preprocess, 13.5ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_249_blur.jpg: 384x640 1 Asc Aorta, 3.7ms
# Speed: 1.7ms preprocess, 3.7ms inference, 6.9ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_249_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_249_clahe.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_249_scaling.jpg: 384x640 1 Asc Aorta, 4.8ms
# Speed: 3.8ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_282.png: 384x640 1 Asc Aorta, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_282_blur.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 2.8ms preprocess, 6.2ms inference, 9.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_282_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 2.3ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_282_clahe.jpg: 384x640 1 Asc Aorta, 4.8ms
# Speed: 3.3ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_282_scaling.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_332.png: 384x640 1 Asc Aorta, 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_332_blur.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.5ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_332_brightness_contrast.jpg: 384x640 1 Asc Aorta, 5.1ms
# Speed: 2.0ms preprocess, 5.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_332_clahe.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 2.6ms preprocess, 6.1ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A K H - 3mensio Screen Recording_longitudinal_view_332_scaling.jpg: 384x640 1 Asc Aorta, 3.0ms
# Speed: 1.1ms preprocess, 3.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_422.png: 320x640 1 Asc Aorta, 11.2ms
# Speed: 1.1ms preprocess, 11.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_422_blur.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_422_brightness_contrast.jpg: 320x640 1 Asc Aorta, 3.0ms
# Speed: 1.2ms preprocess, 3.0ms inference, 0.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_422_clahe.jpg: 320x640 1 Asc Aorta, 3.7ms
# Speed: 2.8ms preprocess, 3.7ms inference, 12.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_422_scaling.jpg: 320x640 1 Asc Aorta, 3.7ms
# Speed: 1.3ms preprocess, 3.7ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_438.png: 320x640 2 Asc Aortas, 3.7ms
# Speed: 2.7ms preprocess, 3.7ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_438_blur.jpg: 320x640 3 Asc Aortas, 6.1ms
# Speed: 1.1ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_438_brightness_contrast.jpg: 320x640 2 Asc Aortas, 3.6ms
# Speed: 2.0ms preprocess, 3.6ms inference, 9.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_438_clahe.jpg: 320x640 1 Asc Aorta, 6.1ms
# Speed: 2.8ms preprocess, 6.1ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_438_scaling.jpg: 320x640 2 Asc Aortas, 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_457.png: 320x640 1 Asc Aorta, 4.8ms
# Speed: 1.6ms preprocess, 4.8ms inference, 5.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_457_blur.jpg: 320x640 2 Asc Aortas, 4.7ms
# Speed: 1.4ms preprocess, 4.7ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_457_brightness_contrast.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 3.2ms preprocess, 6.2ms inference, 3.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_457_clahe.jpg: 320x640 1 Asc Aorta, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M - 3mensio Screen Recording_longitudinal_view_457_scaling.jpg: 320x640 1 Asc Aorta, 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_377.png: 352x640 1 Asc Aorta, 5.1ms
# Speed: 2.2ms preprocess, 5.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_377_blur.jpg: 352x640 1 Asc Aorta, 5.1ms
# Speed: 2.9ms preprocess, 5.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_377_brightness_contrast.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_377_clahe.jpg: 352x640 1 Asc Aorta, 6.7ms
# Speed: 1.4ms preprocess, 6.7ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_377_scaling.jpg: 352x640 1 Asc Aorta, 4.8ms
# Speed: 1.7ms preprocess, 4.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_381.png: 352x640 1 Asc Aorta, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_381_blur.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 3.1ms preprocess, 6.2ms inference, 2.9ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_381_brightness_contrast.jpg: 352x640 1 Asc Aorta, 6.1ms
# Speed: 3.6ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_381_clahe.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_381_scaling.jpg: 352x640 1 Asc Aorta, 5.0ms
# Speed: 3.0ms preprocess, 5.0ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_431.png: 320x640 1 Asc Aorta, 15.5ms
# Speed: 2.6ms preprocess, 15.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_431_blur.jpg: 352x640 1 Asc Aorta, 5.6ms
# Speed: 2.5ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_431_brightness_contrast.jpg: 320x640 1 Asc Aorta, 13.6ms
# Speed: 2.8ms preprocess, 13.6ms inference, 12.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_431_clahe.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A M R - 3mensio Screen Recording_longitudinal_view_431_scaling.jpg: 320x640 1 Asc Aorta, 4.7ms
# Speed: 1.5ms preprocess, 4.7ms inference, 3.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_298.png: 320x640 1 Asc Aorta, 6.1ms
# Speed: 2.4ms preprocess, 6.1ms inference, 9.5ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_298_blur.jpg: 320x640 1 Asc Aorta, 5.0ms
# Speed: 2.7ms preprocess, 5.0ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_298_brightness_contrast.jpg: 320x640 1 Asc Aorta, 6.1ms
# Speed: 2.9ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_298_clahe.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 2.4ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_298_scaling.jpg: 320x640 1 Asc Aorta, 4.6ms
# Speed: 3.1ms preprocess, 4.6ms inference, 10.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_322.png: 320x640 1 Asc Aorta, 6.1ms
# Speed: 2.7ms preprocess, 6.1ms inference, 2.6ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_322_blur.jpg: 320x640 1 Asc Aorta, 4.8ms
# Speed: 1.5ms preprocess, 4.8ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_322_brightness_contrast.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 5.1ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_322_clahe.jpg: 320x640 1 Asc Aorta, 6.1ms
# Speed: 3.1ms preprocess, 6.1ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_322_scaling.jpg: 320x640 1 Asc Aorta, 6.2ms
# Speed: 2.1ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_327.png: 320x640 2 Asc Aortas, 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_327_blur.jpg: 320x640 2 Asc Aortas, 6.2ms
# Speed: 2.5ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_327_brightness_contrast.jpg: 320x640 2 Asc Aortas, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_327_clahe.jpg: 320x640 2 Asc Aortas, 5.9ms
# Speed: 1.4ms preprocess, 5.9ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/A T M F - 3mensio Screen Recording_longitudinal_view_327_scaling.jpg: 320x640 2 Asc Aortas, 5.9ms
# Speed: 2.4ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361.png: 384x640 1 Asc Aorta, 13.5ms
# Speed: 3.5ms preprocess, 13.5ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_blur.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.8ms preprocess, 6.1ms inference, 9.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 2.0ms preprocess, 6.1ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_clahe.jpg: 384x640 1 Asc Aorta, 4.6ms
# Speed: 3.0ms preprocess, 4.6ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_361_scaling.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 2.3ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370.png: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.2ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_blur.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 2.6ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 2.6ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_clahe.jpg: 384x640 1 Asc Aorta, 4.5ms
# Speed: 2.2ms preprocess, 4.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_370_scaling.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 2.8ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376.png: 384x640 1 Asc Aorta, 6.2ms
# Speed: 3.1ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_blur.jpg: 384x640 1 Asc Aorta, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 3.5ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_clahe.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 1.5ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/AA2114312_TR - 3mensio Screen Recording_longitudinal_view_376_scaling.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_100.png: 352x640 1 Asc Aorta, 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_100_blur.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 9.8ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_100_brightness_contrast.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 3.1ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_100_clahe.jpg: 352x640 1 Asc Aorta, 4.7ms
# Speed: 1.4ms preprocess, 4.7ms inference, 3.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_100_scaling.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_114.png: 352x640 1 Asc Aorta, 6.1ms
# Speed: 2.9ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_114_blur.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 2.6ms preprocess, 6.2ms inference, 11.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_114_brightness_contrast.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_114_clahe.jpg: 352x640 2 Asc Aortas, 4.8ms
# Speed: 2.4ms preprocess, 4.8ms inference, 8.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_114_scaling.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 10.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_120.png: 352x640 1 Asc Aorta, 6.1ms
# Speed: 2.6ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_120_blur.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_120_brightness_contrast.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_120_clahe.jpg: 352x640 1 Asc Aorta, 4.7ms
# Speed: 2.2ms preprocess, 4.7ms inference, 3.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/Anonymous_longitudinal_view_120_scaling.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 1.9ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/B D - 3mensio Screen Recording_longitudinal_view_288.png: 320x640 1 Asc Aorta, 13.5ms
# Speed: 2.8ms preprocess, 13.5ms inference, 12.2ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/B D - 3mensio Screen Recording_longitudinal_view_288_blur.jpg: 320x640 1 Asc Aorta, 6.2ms
# ...
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R K - 3mensio Screen Recording_longitudinal_view_192_blur.jpg: 384x640 1 Asc Aorta, 6.0ms
# Speed: 3.3ms preprocess, 6.0ms inference, 9.5ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R K - 3mensio Screen Recording_longitudinal_view_192_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.7ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R K - 3mensio Screen Recording_longitudinal_view_192_clahe.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 2.7ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R K - 3mensio Screen Recording_longitudinal_view_192_scaling.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.3ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_212.png: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_212_blur.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_212_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.0ms
# Speed: 2.4ms preprocess, 6.0ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_212_clahe.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.5ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_212_scaling.jpg: 384x640 1 Asc Aorta, 6.0ms
# Speed: 3.7ms preprocess, 6.0ms inference, 12.1ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_259.png: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_259_blur.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.5ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_259_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.6ms preprocess, 6.1ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_259_clahe.jpg: 384x640 1 Asc Aorta, 4.7ms
# Speed: 1.6ms preprocess, 4.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_259_scaling.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 3.7ms preprocess, 6.2ms inference, 12.2ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_289.png: 384x640 1 Asc Aorta, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_289_blur.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_289_brightness_contrast.jpg: 384x640 1 Asc Aorta, 6.2ms
# Speed: 3.2ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_289_clahe.jpg: 384x640 1 Asc Aorta, 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R M- 3mensio Screen Recording_longitudinal_view_289_scaling.jpg: 384x640 1 Asc Aorta, 5.8ms
# Speed: 2.1ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_407.png: 416x640 1 Asc Aorta, 13.6ms
# Speed: 2.4ms preprocess, 13.6ms inference, 11.7ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_407_blur.jpg: 416x640 1 Asc Aorta, 6.1ms
# Speed: 2.5ms preprocess, 6.1ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_407_brightness_contrast.jpg: 416x640 1 Asc Aorta, 6.1ms
# Speed: 2.8ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_407_clahe.jpg: 416x640 1 Asc Aorta, 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 12.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_407_scaling.jpg: 416x640 1 Asc Aorta, 6.0ms
# Speed: 3.7ms preprocess, 6.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_474.png: 416x640 1 Asc Aorta, 6.2ms
# Speed: 2.0ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_474_blur.jpg: 416x640 1 Asc Aorta, 6.1ms
# Speed: 2.9ms preprocess, 6.1ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_474_brightness_contrast.jpg: 416x640 1 Asc Aorta, 6.1ms
# Speed: 3.0ms preprocess, 6.1ms inference, 12.4ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_474_clahe.jpg: 416x640 1 Asc Aorta, 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 12.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_474_scaling.jpg: 416x640 1 Asc Aorta, 5.9ms
# Speed: 2.2ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_526.png: 384x640 1 Asc Aorta, 13.5ms
# Speed: 2.8ms preprocess, 13.5ms inference, 12.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_526_blur.jpg: 384x640 1 Asc Aorta, 6.1ms
# Speed: 2.1ms preprocess, 6.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_526_brightness_contrast.jpg: 416x640 1 Asc Aorta, 13.5ms
# Speed: 2.8ms preprocess, 13.5ms inference, 12.2ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_526_clahe.jpg: 416x640 1 Asc Aorta, 6.1ms
# Speed: 4.0ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 416, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/R R S - 3mensio Screen Recording_longitudinal_view_526_scaling.jpg: 384x640 1 Asc Aorta, 13.5ms
# Speed: 3.8ms preprocess, 13.5ms inference, 12.3ms postprocess per image at shape (1, 3, 384, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459.png: 320x640 1 Asc Aorta, 11.5ms
# Speed: 1.2ms preprocess, 11.5ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_blur.jpg: 352x640 1 Asc Aorta, 13.5ms
# Speed: 2.3ms preprocess, 13.5ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_brightness_contrast.jpg: 320x640 1 Asc Aorta, 3.5ms
# Speed: 1.2ms preprocess, 3.5ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_clahe.jpg: 320x640 1 Asc Aorta, 6.1ms
# Speed: 2.8ms preprocess, 6.1ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_459_scaling.jpg: 320x640 1 Asc Aorta, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547.png: 320x640 1 Asc Aorta, 3.7ms
# Speed: 2.5ms preprocess, 3.7ms inference, 12.4ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_blur.jpg: 352x640 1 Asc Aorta, 11.1ms
# Speed: 2.1ms preprocess, 11.1ms inference, 12.2ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_brightness_contrast.jpg: 320x640 1 Asc Aorta, 12.0ms
# Speed: 1.2ms preprocess, 12.0ms inference, 12.3ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_clahe.jpg: 320x640 1 Asc Aorta, 3.5ms
# Speed: 2.4ms preprocess, 3.5ms inference, 0.7ms postprocess per image at shape (1, 3, 320, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_547_scaling.jpg: 352x640 1 Asc Aorta, 11.0ms
# Speed: 1.4ms preprocess, 11.0ms inference, 12.2ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614.png: 352x640 1 Asc Aorta, 4.4ms
# Speed: 1.2ms preprocess, 4.4ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_blur.jpg: 352x640 1 Asc Aorta, 4.6ms
# Speed: 1.1ms preprocess, 4.6ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_brightness_contrast.jpg: 352x640 1 Asc Aorta, 5.6ms
# Speed: 1.8ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_clahe.jpg: 352x640 1 Asc Aorta, 6.1ms
# Speed: 3.3ms preprocess, 6.1ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RANIERI, MARIO - 3mensio Screen Recording_longitudinal_view_614_scaling.jpg: 352x640 1 Asc Aorta, 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309.png: 352x640 1 Asc Aorta, 4.6ms
# Speed: 2.6ms preprocess, 4.6ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_blur.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 2.8ms preprocess, 6.2ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_brightness_contrast.jpg: 352x640 1 Asc Aorta, 5.5ms
# Speed: 1.7ms preprocess, 5.5ms inference, 12.4ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_clahe.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 3.0ms preprocess, 6.2ms inference, 2.5ms postprocess per image at shape (1, 3, 352, 640)
#
# image 1/1 /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/aorta_data/images/train/RIVAS SEGURA, LUIS - 3mensio Screen Recording_longitudinal_view_309_scaling.jpg: 352x640 1 Asc Aorta, 6.2ms
# Speed: 1.6ms preprocess, 6.2ms inference, 12.3ms postprocess per image at shape (1, 3, 352, 640)
# ✅ Mapping complete! Final images saved in /mnt/nvme_disk2/User_data/nb57077k/cardiovision/phase2/Dataset/mapped_predictions
